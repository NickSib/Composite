# %% [markdown]
# ##### Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ##### Импорт датасета

# %%
X_bp = pd.read_excel('C:/Users/rossi/data/vkr_set/X_bp.xlsx', index_col=0)
X_nup = pd.read_excel('C:/Users/rossi/data/vkr_set/X_nup.xlsx', index_col=0)

# %%
X_bp.head()
# Out:
#    Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                         1.857143            2030.0             738.736842
# 1                         1.857143            2030.0             738.736842
# 2                         1.857143            2030.0             738.736842
# 3                         1.857143            2030.0             738.736842
# 4                         2.771331            2030.0             753.000000
#
#    Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# 0                        30.00                        22.267857
# 1                        50.00                        23.750000
# 2                        49.90                        33.000000
# 3                       129.00                        21.250000
# 4                       111.86                        22.267857
#
#    Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# 0                100.000000                          210.0
# ...

# %%
X_nup.head()
# Out:
#    Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                   0          4.0               57.0
# 1                   0          4.0               60.0
# 2                   0          4.0               70.0
# 3                   0          5.0               47.0
# 4                   0          5.0               57.0

# %%
set = X_bp.join(X_nup)
set.head()
# Out:
#    Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                         1.857143            2030.0             738.736842
# 1                         1.857143            2030.0             738.736842
# 2                         1.857143            2030.0             738.736842
# 3                         1.857143            2030.0             738.736842
# 4                         2.771331            2030.0             753.000000
#
#    Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# 0                        30.00                        22.267857
# 1                        50.00                        23.750000
# 2                        49.90                        33.000000
# 3                       129.00                        21.250000
# 4                       111.86                        22.267857
#
#    Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# 0                100.000000                          210.0
# ...

# %% [markdown]
# ##### Разведочный анализа данных

# %%
print(set.shape)
# Out:
# (1023, 13)

# %%
set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Соотношение матрица-наполнитель       1023 non-null   float64
#  1   Плотность, кг/м3                      1023 non-null   float64
#  2   модуль упругости, ГПа                 1023 non-null   float64
#  3   Количество отвердителя, м.%           1023 non-null   float64
#  4   Содержание эпоксидных групп,%_2       1023 non-null   float64
#  5   Температура вспышки, С_2              1023 non-null   float64
#  6   Поверхностная плотность, г/м2         1023 non-null   float64
#  7   Модуль упругости при растяжении, ГПа  1023 non-null   float64
#  8   Прочность при растяжении, МПа         1023 non-null   float64
#  9   Потребление смолы, г/м2               1023 non-null   float64
# ...

# %%
set.describe()
# Out:
#        Соотношение матрица-наполнитель  Плотность, кг/м3  \
# count                      1023.000000       1023.000000
# mean                          2.930366       1975.734888
# std                           0.913222         73.729231
# min                           0.389403       1731.764635
# 25%                           2.317887       1924.155467
# 50%                           2.906878       1977.621657
# 75%                           3.552660       2021.374375
# max                           5.591742       2207.773481
#
#        модуль упругости, ГПа  Количество отвердителя, м.%  \
# count            1023.000000                  1023.000000
# mean              739.923233                   110.570769
# std               330.231581                    28.295911
# min                 2.436909                    17.740275
# 25%               500.047452                    92.443497
# 50%               739.664328                   110.564840
# ...

# %% [markdown]
# ##### Проверка на пустые значения

# %%
set.isnull().sum()
# Out:
# Соотношение матрица-наполнитель         0
# Плотность, кг/м3                        0
# модуль упругости, ГПа                   0
# Количество отвердителя, м.%             0
# Содержание эпоксидных групп,%_2         0
# Температура вспышки, С_2                0
# Поверхностная плотность, г/м2           0
# Модуль упругости при растяжении, ГПа    0
# Прочность при растяжении, МПа           0
# Потребление смолы, г/м2                 0
# Угол нашивки, град                      0
# Шаг нашивки                             0
# Плотность нашивки                       0
# dtype: int64

# %% [markdown]
# ##### Переименование колонок

# %%
set = set.rename(columns={"Соотношение матрица-наполнитель":"Tar3. Соотношение матрица-наполнитель",
                         "Плотность, кг/м3": "Плотность",
                         "модуль упругости, ГПа": "Модуль упругости",
                         "Количество отвердителя, м.%": "Количество отвердителя",
                         "Содержание эпоксидных групп,%_2": "Содержание эпоксидных групп",
                         "Температура вспышки, С_2": "Температура вспышки",
                         "Поверхностная плотность, г/м2": "Поверхностная плотность",
                         "Модуль упругости при растяжении, ГПа": "Tar1. Модуль упругости при растяжении",
                         "Прочность при растяжении, МПа": "Tar2. Прочность при растяжении",
                         "Потребление смолы, г/м2": "Потребление смолы",
                         "Угол нашивки, град": "Угол нашивки"
                         })

# %%
set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1023 entries, 0 to 1022
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Tar3. Соотношение матрица-наполнитель  1023 non-null   float64
#  1   Плотность                              1023 non-null   float64
#  2   Модуль упругости                       1023 non-null   float64
#  3   Количество отвердителя                 1023 non-null   float64
#  4   Содержание эпоксидных групп            1023 non-null   float64
#  5   Температура вспышки                    1023 non-null   float64
#  6   Поверхностная плотность                1023 non-null   float64
#  7   Tar1. Модуль упругости при растяжении  1023 non-null   float64
#  8   Tar2. Прочность при растяжении         1023 non-null   float64
#  9   Потребление смолы                      1023 non-null   float64
# ...

# %%
set.describe()
# Out:
#        Tar3. Соотношение матрица-наполнитель    Плотность  Модуль упругости  \
# count                            1023.000000  1023.000000       1023.000000
# mean                                2.930366  1975.734888        739.923233
# std                                 0.913222    73.729231        330.231581
# min                                 0.389403  1731.764635          2.436909
# 25%                                 2.317887  1924.155467        500.047452
# 50%                                 2.906878  1977.621657        739.664328
# 75%                                 3.552660  2021.374375        961.812526
# max                                 5.591742  2207.773481       1911.536477
#
#        Количество отвердителя  Содержание эпоксидных групп  \
# count             1023.000000                  1023.000000
# mean               110.570769                    22.244390
# std                 28.295911                     2.406301
# ...

# %% [markdown]
# ##### Корреляция

# %%
cmap = sns.diverging_palette(260, 3, as_cmap=True)

sns.heatmap(set.corr(), cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
set.corr()['Tar1. Модуль упругости при растяжении'].sort_values()
# Out:
# Количество отвердителя                  -0.065929
# Шаг нашивки                             -0.029468
# Плотность                               -0.017602
# Tar2. Прочность при растяжении          -0.009009
# Tar3. Соотношение матрица-наполнитель   -0.008411
# Плотность нашивки                        0.006476
# Угол нашивки                             0.023003
# Модуль упругости                         0.023267
# Температура вспышки                      0.028414
# Поверхностная плотность                  0.036702
# Потребление смолы                        0.050938
# Содержание эпоксидных групп              0.056828
# Tar1. Модуль упругости при растяжении    1.000000
# Name: Tar1. Модуль упругости при растяжении, dtype: float64

# %%
set.corr()['Tar2. Прочность при растяжении'].sort_values()
# Out:
# Количество отвердителя                  -0.075375
# Плотность                               -0.069981
# Шаг нашивки                             -0.059547
# Температура вспышки                     -0.031763
# Содержание эпоксидных групп             -0.023899
# Tar1. Модуль упругости при растяжении   -0.009009
# Поверхностная плотность                 -0.003210
# Плотность нашивки                        0.019604
# Угол нашивки                             0.023398
# Tar3. Соотношение матрица-наполнитель    0.024148
# Потребление смолы                        0.028602
# Модуль упругости                         0.041868
# Tar2. Прочность при растяжении           1.000000
# Name: Tar2. Прочность при растяжении, dtype: float64

# %%
set.corr()['Tar3. Соотношение матрица-наполнитель'].sort_values()
# Out:
# Угол нашивки                            -0.031073
# Tar1. Модуль упругости при растяжении   -0.008411
# Количество отвердителя                  -0.006445
# Поверхностная плотность                 -0.006272
# Температура вспышки                     -0.004776
# Плотность нашивки                       -0.004652
# Плотность                                0.003841
# Содержание эпоксидных групп              0.019766
# Tar2. Прочность при растяжении           0.024148
# Модуль упругости                         0.031700
# Шаг нашивки                              0.036437
# Потребление смолы                        0.072531
# Tar3. Соотношение матрица-наполнитель    1.000000
# Name: Tar3. Соотношение матрица-наполнитель, dtype: float64

# %% [markdown]
# ##### Выбросы

# %%
columns = list(set)

fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(30, 100)) 
for index, column in enumerate(columns):
 i, j = divmod(index, 3)
 sns.boxplot(data=set[column], ax=axs[i,j]).set_title(column, fontsize=20)

# %% [markdown]
# #удаление аномалии и выбросов
#
# Q1 = set.quantile(0.25)
# Q3 = set.quantile(0.75)
# IQR = Q3 - Q1
#
# set = set[~((set < (Q1 - 1.5 * IQR)) |(set > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# ##### Распределение

# %%
columns = list(set)

fig, axs = plt.subplots(nrows=5, ncols=3, figsize=(30, 100)) 
for index, column in enumerate(columns):
 i, j = divmod(index, 3)
 sns.histplot(data=set[column], ax=axs[i,j], kde = True).set_title(column, fontsize=20)

# %%
sns.pairplot(set.head(100), diag_kind='kde')

# %% [markdown]
# Вывод: наблюдается небольшое смещение фичи "Поверхностная плотность" и отсутствие нормального распределения фичи "Угол нашивки"

# %% [markdown]
# ##### Разделение данных на Х и у

# %%
set_split = set.copy()
print(set_split.shape)
# Out:
# (1023, 13)

# %%
# Исключаем из входного датасета y3, которая по сценарию изначально не известна;
# Обучаем модели и прогнозируем y1 и y2;
# Добавляем в датасет спрогнозированные y1, y2, исходный y3 и прогнозируем y3. 

y1 = set_split['Tar1. Модуль упругости при растяжении']
y2 = set_split['Tar2. Прочность при растяжении']
y3 = set_split['Tar3. Соотношение матрица-наполнитель']

X1 = set_split.drop(['Tar3. Соотношение матрица-наполнитель', 'Tar1. Модуль упругости при растяжении'], axis = 1)  
X2 = set_split.drop(['Tar3. Соотношение матрица-наполнитель', 'Tar2. Прочность при растяжении'], axis = 1)      
X3 = set_split.drop(['Tar1. Модуль упругости при растяжении','Tar2. Прочность при растяжении',
                     'Tar3. Соотношение матрица-наполнитель'], axis = 1)  

print(y1.shape)
print(X1.shape)

print(y2.shape)
print(X2.shape)

print(y3.shape)
print(X3.shape)
# Out:
# (1023,)
# (1023, 11)
# (1023,)
# (1023, 11)
# (1023,)
# (1023, 10)

# %% [markdown]
# ##### Масштабирование и разделение на выборки

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
Sc_X1 = scaler.fit_transform(X1)
Sc_X2 = scaler.fit_transform(X2)
Sc_X3 = scaler.fit_transform(X3)

X1 = Sc_X1
X2 = Sc_X2
X3 = Sc_X3

print(X1.shape)
print(X2.shape)
print(X3.shape)
# Out:
# (1023, 11)
# (1023, 11)
# (1023, 10)

# %% [markdown]
# ##### Посмотрим на итоговый набор данных на примере X1

# %%
X1_standart = pd.DataFrame(data = X1, columns = [
                                             'Плотность',
                                             'Модуль упругости',
                                             'Количество отвердителя',
                                             'Содержание эпоксидных групп',
                                             'Температура вспышки',
                                             'Поверхностная плотность',
                                             'Tar2. Прочность при растяжении',
                                             'Потребление смолы',
                                             'Угол нашивки',
                                             'Шаг нашивки',
                                             'Плотность нашивки'])


#pd_standart_y = pd.DataFrame(data = y_tar1, columns = ['Tar1. Модуль упругости при растяжении'])

#pd_standart_tar1 = pd_standart_X.join(pd_standart_y)
#pd_standart_tar1.describe()

# %% [markdown]
# ##### Видим, что данные отмасштабировались

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(1, 4, figsize=(12, 4))

#sns.histplot(data=set, x="Tar1. Модуль упругости при растяжении", kde=True, ax=axs[0], color='green')
sns.histplot(data=set, x="Плотность нашивки", kde=True, ax=axs[0], color='skyblue')
sns.histplot(data=set, x="Шаг нашивки", kde=True, ax=axs[1], color='orange')

#sns.histplot(data=aaa, x="Tar1. Модуль упругости при растяжении", kde=True, ax=axs[0], color='green')
sns.histplot(data=X1_standart, x="Плотность нашивки", kde=True, ax=axs[2], color='skyblue')
sns.histplot(data=X1_standart, x="Шаг нашивки", kde=True, ax=axs[3], color='orange')
# Out:
# <AxesSubplot:xlabel='Шаг нашивки', ylabel='Count'>

# %% [markdown]
# Вывод: на примере фич Tar2 и Tar3 видно, что данные отмасштабированы

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, shuffle = True, random_state=42)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3, shuffle = True, random_state=42)

# %% [markdown]
# ##### Построение регрессионной модели для предсказания "Tar1. Модуль упругости при растяжении"

# %%
# X1_train, X1_test, y1_train, y1_test

print(X1_train.shape)
print(y1_train.shape)
print(X1_test.shape)
print(y1_test.shape)
# Out:
# (716, 11)
# (716,)
# (307, 11)
# (307,)

# %% [markdown]
# ##### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
ln_model = LinearRegression()
ln_model.fit(X1_train, y1_train)
y1_pred_ln = ln_model.predict(X1_test)

print('MAE:', mean_absolute_error(y1_test, y1_pred_ln)) 
print('MSE:', mean_squared_error(y1_test, y1_pred_ln)) 
print('r2:', r2_score(y1_test, y1_pred_ln))
m1_ln = (mean_absolute_error (y1_test, y1_pred_ln) / y1_test.mean()) * 100
print('(MAE/test_mean)x100:', m1_ln)
print('Точность модели:', 100 - m1_ln)
# Out:
# MAE: 2.5571035925102468
# MSE: 10.118841188115416
# r2: -0.018563613121253653
# (MAE/test_mean)x100: 3.4737922466694307
# Точность модели: 96.52620775333057

# %% [markdown]
# ##### Сохранение модели для flask-приложения

# %%
import pickle
pickle.dump(ln_model, open('ln_model.pkl','wb'))

# %% [markdown]
# ##### Метрики на train и test

# %%
y1_pred_ln_train = ln_model.predict(X1_train)
y1_pred_ln_test = ln_model.predict(X1_test)

print('MAE_train:', mean_absolute_error(y1_train, y1_pred_ln_train))
print('MAE_test:', mean_absolute_error(y1_test, y1_pred_ln_test)) 

print('MSE_train:', mean_squared_error(y1_train, y1_pred_ln_train))
print('MSE_test:', mean_squared_error(y1_test, y1_pred_ln_test))

print('r2_train:', r2_score(y1_train, y1_pred_ln_train))
print('r2_test:', r2_score(y1_test, y1_pred_ln_test))

print('Точность модели на трейне:', 100 - (mean_absolute_error (y1_train, y1_pred_ln_train) / y1_train.mean()) * 100)
print('Точность модели на тесте:', 100 - (mean_absolute_error (y1_test, y1_pred_ln_test) / y1_test.mean()) * 100)
# Out:
# MAE_train: 2.4613192952688316
# MAE_test: 2.5571035925102468
# MSE_train: 9.379429049269936
# MSE_test: 10.118841188115416
# r2_train: 0.02063112061922867
# r2_test: -0.018563613121253653
# Точность модели на трейне: 96.63787934635941
# Точность модели на тесте: 96.52620775333057

# %% [markdown]
# ##### Random Forest Regression with Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
parameters_rf = {
    'n_estimators': [50, 100, 150],
    'max_depth': [2, 3],
    'criterion': ['squared_error', 'absolute_error', 'poisson'],
    'max_features': ['auto', 'sqrt', 'log2']}

# %%
rf_model = RandomForestRegressor()

grid_search_rf = GridSearchCV(estimator = rf_model, param_grid = parameters_rf, cv=10)
grid_search_rf.fit(X1_train, y1_train) 
best_rf_model = grid_search_rf.best_estimator_ 

grid_search_rf.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 2,
#  'max_features': 'sqrt',
#  'n_estimators': 100}

# %%
y1_pred_rf = best_rf_model.predict(X1_test)

print('MAE:', mean_absolute_error(y1_test, y1_pred_rf))
print('MSE:', mean_squared_error(y1_test, y1_pred_rf)) 
print('r2:', r2_score(y1_test, y1_pred_rf))
m1_rf = (mean_absolute_error (y1_test, y1_pred_rf) / y1_test.mean()) * 100 
print('(MAE/test_mean)x100:', m1_rf)
print('Точность модели:', 100 - m1_rf)
# Out:
# MAE: 2.5663064711028634
# MSE: 10.157062544725344
# r2: -0.022410978878187215
# (MAE/test_mean)x100: 3.4862942385307334
# Точность модели: 96.51370576146927

# %% [markdown]
# ##### Построение регрессионной модели для предсказания "Tar2. Прочность при растяжении"

# %%
# X2_train, X2_test, y2_train, y2_test

print(X2_train.shape)
print(y2_train.shape)
print(X2_test.shape)
print(y2_test.shape)
# Out:
# (716, 11)
# (716,)
# (307, 11)
# (307,)

# %% [markdown]
# ##### Support Vector Regression

# %%
from sklearn import svm

# %%
svr_model = svm.SVR()
svr_model.fit(X2_train, y2_train)
y2_pred_svr = svr_model.predict(X2_test)

print('MAE:', mean_absolute_error(y2_test, y2_pred_svr))
print('MSE:', mean_squared_error(y2_test, y2_pred_svr)) 
print('r2:', r2_score(y2_test, y2_pred_svr))
m2_svr = (mean_absolute_error (y2_test, y2_pred_svr) / y2_test.mean()) * 100
print('(MAE/test_mean)x100:', m2_svr)
print('Точность модели:', 100 - m2_svr)
# Out:
# MAE: 379.49073002317033
# MSE: 224363.41712439575
# r2: -0.0018999986387733259
# (MAE/test_mean)x100: 15.348495967420082
# Точность модели: 84.65150403257992

# %% [markdown]
# ##### Decision Tree Regression with Random Search

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
parameters_tree = {
    'splitter' : ['best', 'random'],
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'max_depth': [2, 4, 5]
     }

# %%
tree_model = DecisionTreeRegressor()

random_search_tree = RandomizedSearchCV(tree_model, 
                                        param_distributions=parameters_tree, 
                                        n_iter = 10, cv=10)

random_search_tree.fit(X2_train, y2_train) 
best_tree_model = random_search_tree.best_estimator_ 

random_search_tree.best_params_
# Out:
# {'splitter': 'random', 'max_depth': 2, 'criterion': 'friedman_mse'}

# %%
y2_pred_tree = best_tree_model.predict(X2_test)

print('MAE:', mean_absolute_error(y2_test, y2_pred_tree))
print('MSE:', mean_squared_error(y2_test, y2_pred_tree))
print('r2:', r2_score(y2_test, y2_pred_tree))
m2_tree = (mean_absolute_error (y2_test, y2_pred_tree) / y2_test.mean()) * 100 
print('(MAE/test_mean)x100:', m2_tree)
print('Точность модели:', 100 - m2_tree)
# Out:
# MAE: 375.49260066065693
# MSE: 221862.41041664407
# r2: 0.00926830432793846
# (MAE/test_mean)x100: 15.186791694975762
# Точность модели: 84.81320830502423

# %% [markdown]
# ##### Бенчмаркинг результативности моделей

# %%
accuracy = pd.DataFrame({'Target' : ['Tar1. Модуль упругости при растяжении', 'Tar1. Модуль упругости при растяжении',
                              'Tar2. Прочность при растяжении', 'Tar2. Прочность при растяжении'],
                      'Model' : ['Linear Regression', 'RandomForest Regression with Grid Search',
                                  'Support Vector Regression', 'TDecision Tree Regressor with Random Search'],
                          'MAE' : [mean_absolute_error(y1_test, y1_pred_ln), mean_absolute_error(y1_test, y1_pred_rf),
                              mean_absolute_error(y2_test, y2_pred_svr), mean_absolute_error(y2_test, y2_pred_tree)],
                      'MSE' : [mean_squared_error(y1_test, y1_pred_ln), mean_squared_error(y1_test, y1_pred_rf),
                              mean_squared_error(y2_test, y2_pred_svr), mean_squared_error(y2_test, y2_pred_tree)],
                      'R2' : [r2_score(y1_test, y1_pred_ln), r2_score(y1_test, y1_pred_rf),
                              r2_score(y1_test, y2_pred_svr), r2_score(y1_test, y2_pred_tree)],
                      'accuracy' : [100 - m1_ln, 100 - m1_rf, 100 - m2_svr, 100 - m2_tree]})
accuracy
# Out:
#                                   Target  \
# 0  Tar1. Модуль упругости при растяжении
# 1  Tar1. Модуль упругости при растяжении
# 2         Tar2. Прочность при растяжении
# 3         Tar2. Прочность при растяжении
#
#                                          Model         MAE            MSE  \
# 0                            Linear Regression    2.557104      10.118841
# 1     RandomForest Regression with Grid Search    2.567349      10.160625
# 2                    Support Vector Regression  379.490730  224363.417124
# 3  TDecision Tree Regressor with Random Search  378.859418  223749.967263
#
#               R2   accuracy
# 0      -0.018564  96.526208
# 1      -0.022770  96.512289
# 2 -569632.206020  84.651504
# 3 -573986.987878  84.677037

# %% [markdown]
# ##### По результатам бенчмаркинга выбираем две наилучшие модели и прогнозируем целевые переменные
# ##### 'Tar1. Модуль упругости при растяжении' и 'Tar2. Прочность при растяжении',
# ##### необходимые для прогнозирования переменной  'Tar3. Соотношение матрица-наполнитель'

# %%
y1_pred = ln_model.predict(X1) # прогнозирование y1
y2_pred = svr_model.predict(X2) # прогнозирование y2
#print(y1_pred.shape)
#print(y2_pred.shape)
y1_pred = y1_pred.reshape(-1, 1) # корректировка размерности для стандартизации
y2_pred = y2_pred.reshape(-1, 1) # корректировка размерности для стандартизации

scaler = StandardScaler()
pd_y1_sc = scaler.fit_transform(y1_pred) # стандартизация
pd_y2_sc = scaler.fit_transform(y2_pred) # стандартизация

y1_pred = pd_y1_sc # запись в у1
y2_pred = pd_y2_sc # запись в у2

#print(y1_pred.shape)
#print(y2_pred.shape)

ff = np.hstack((X3, y1_pred, y2_pred)) # cклейка Х3
print(ff.shape)
# Out:
# (1023, 12)

# %%
dft = pd.DataFrame(data = ff, columns = [
                                            'Плотность',
                                            'Модуль упругости',
                                            'Количество отвердителя',
                                            'Содержание эпоксидных групп',
                                            'Температура вспышки',
                                            'Поверхностная плотность',
                                            'Потребление смолы',
                                            'Угол нашивки',
                                            'Шаг нашивки',
                                            'Плотность нашивки',
'Tar1. Модуль упругости при растяжении',
'Tar2. Прочность при растяжении'])
dft.head()
# Out:
#    Плотность  Модуль упругости  Количество отвердителя  \
# 0   0.736365         -0.003594               -2.848828
# 1   0.736365         -0.003594               -2.141666
# 2   0.736365         -0.003594               -2.145202
# 3   0.736365         -0.003594                0.651622
# 4   0.736365          0.039618                0.045585
#
#    Содержание эпоксидных групп  Температура вспышки  Поверхностная плотность  \
# 0                     0.009757            -4.542215                -0.969964
# 1                     0.626001            -0.030955                -0.969964
# 2                     4.471955            -0.030955                -0.969964
# 3                    -0.413446             0.344984                -0.969964
# 4                     0.009757            -0.030955                -0.969964
#
#    Потребление смолы  Угол нашивки  Шаг нашивки  Плотность нашивки  \
# 0            0.02641     -0.983518    -1.131530          -0.012469
# ...

# %% [markdown]
# ##### Построение нейронной сети для предсказания "Tar3. Соотношение матрица-наполнитель"

# %%
print(ff.shape)
# Out:
# (1023, 12)

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(ff, y3, test_size=0.3, shuffle = True, random_state=42)

# %%
# X3_train, X3_test, y3_train, y3_test

print(X3_train.shape)
print(y3_train.shape)
print(X3_test.shape)
print(y3_test.shape)
# Out:
# (716, 12)
# (716,)
# (307, 12)
# (307,)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.10.1

# %% [markdown]
# ##### Моя модель

# %%
import keras_tuner
from tensorflow.keras import models, layers
from keras_tuner.tuners import RandomSearch, Hyperband, BayesianOptimization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
model_ns = tf.keras.models.Sequential()
model_ns.add(tf.keras.Input(shape=(12,)))
#model_ns.add(tf.keras.layers.Dense(12, input_shape=[X3_train.shape[1]]))
#model_ns.add(tf.keras.layers.Dense(8))
#model_ns.add(Dense(32, input_dim=12, activation='relu'))
#model_ns.add(layers.Dropout(0.3)), #вероятность 0,3
#model_ns.add(tf.keras.layers.Dense(1))
model_ns.add(Dense(1, input_dim=12, activation='linear'))


    # к скрытому или входу: activation='tanh', bias_initializer='glorot_normal', kernel_initializer='glorot_normal')) 
    # к скрытому или входу :activation='tanh', bias_initializer='he_normal', kernel_initializer='he_normal'))    
    # к выходу: activation='linear', bias_initializer='he_normal', kernel_initializer='he_normal'))

#sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
    
model_ns.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    #optimizer=tf.optimizers.Adam(learning_rate=0.1),
    #optimizer=sgd,
    loss='mean_absolute_error')

model_ns.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 13
#
# ...
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
history_ns = model_ns.fit(
    X3_train,
    y3_train,
    epochs=300,
    verbose=0,
    validation_split = 0.2)
# Out:
# CPU times: total: 24.4 s
# Wall time: 21.9 s

# %%
#history_ns.history

# %%
def plot_loss_ns(history_ns):
    plt.plot(history_ns.history['loss'], label='loss')
    plt.plot(history_ns.history['val_loss'], label='val_loss')
    plt.ylim([0.5,2])
    plt.xlabel('Эпоха')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
plot_loss_ns(history_ns)

# %%
mae_ns = model_ns.evaluate(X3_test, y3_test, verbose=0)
print('MAE:', mae_ns)
print('Точность модели:', 100- (mae_ns / y3_test.mean() * 100))
# Out:
# MAE: 0.7650960087776184
# Точность модели: 74.07735800719789

# %% [markdown]
# ##### Повторно обучаем

# %%
# %%time
history_ns = model_ns.fit(
    X3_train,
    y3_train,
    epochs=300,
    verbose=0,
    validation_split = 0.2)
# Out:
# CPU times: total: 28 s
# Wall time: 30.4 s

# %%
mae_ns = model_ns.evaluate(X3_test, y3_test, verbose=0)
print('MAE:', mae_ns)
print('Точность модели:', 100- (mae_ns / y3_test.mean() * 100))
# Out:
# MAE: 0.7639831304550171
# Точность модели: 74.11506405455322

# %% [markdown]
# ##### Keras Tuner

# %%
def tuner_model(hp):
    model = Sequential()
    
    activation_choice = hp.Choice('activation', values=['relu', 'sigmoid', 'tanh', 'elu', 'selu']) 
                
# сетка параметров входного слоя
    
    model.add(Dense(units=hp.Int('units_input',    
                                   min_value=12,    
                                   max_value=36,   
                                   step=2),
                                   input_dim = X3_train.shape[1], #input_shape=(X3_train.shape[1])
                                   activation = activation_choice))
    
# сетка кол-ва слоев и их параметров:

    for i in range(hp.Int('num_layers', 2, 5)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=128,
                                            step=32),
                                            activation = activation_choice))
                
    model.add(Dense(1, activation='linear'))
              
    model.compile(
        optimizer=hp.Choice('optimizer', values=['adam','rmsprop','SGD']),
        loss='mean_absolute_error', 
        metrics=['mean_absolute_error'])   

    return model

# %%
def tuner_model(hp):
    model = Sequential()
    
    activation_choice = hp.Choice('activation', values=['relu', 'sigmoid', 'tanh', 'elu', 'selu']) 
                
# сетка параметров входного слоя
    
    model.add(Dense(units=hp.Int('units_input',    # Полносвязный слой с разным количеством нейронов
                                   min_value=12,    # минимальное количество нейронов - 128
                                   max_value=36,   # максимальное количество - 1024
                                   step=2),
                                   input_dim = X3_train.shape[1], #input_shape=(X3_train.shape[1])
                                   activation = activation_choice))
    
# сетка кол-ва слоев и их параметров:

    for i in range(hp.Int('num_layers', 2, 5)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=128,
                                            step=32),
                                            activation = activation_choice))
'''
#сетка параметров скрытого слоя
    
    #model.add(Dense(units=hp.Int('units_hidden',        
                                   #min_value=12,   
                                   #max_value=64,   
                                   #step=2),
                    #activation=activation_choice))
    
# cетка параметров дропаут слоя
    
    #model.add(layers.Dropout(hp.Float('dropout',
                                       #min_value=0.0,
                                       #max_value=0.5,
                                       #step=0.5)))
'''                
    model.add(Dense(1, activation='linear'))
              
    model.compile(
        optimizer=hp.Choice('optimizer', values=['adam','rmsprop','SGD']),
        loss='mean_absolute_error',    # 'mean_absolute_error'
        metrics=['mean_absolute_error'])   # 'mean_absolute_error'

# сетка параметров конкретного оптимайзера
    
    #model.compile(
        #optimizer=keras.optimizers.Adam(
            #hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),

        
    return model

# %%
tuner = RandomSearch(
            tuner_model, # функция создания модели
            objective='val_mean_absolute_error', #метрика, которую нужно оптимизироват # incase of classification it will be val_accuracy
            #seed=42,
            max_trials=5, # кол-во создаваемых моделей
            #executions_per_trial=2
            directory='project', # каталог, куда сохраняются обученные сети
            project_name='ВКР')

# tuner = Hyperband
# tuner = BayesianOptimization
# tuner = keras_tuner.SklearnTuner

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh', 'elu', 'selu'], 'ordered': False}
# units_input (Int)
# {'default': None, 'conditions': [], 'min_value': 12, 'max_value': 36, 'step': 2, 'sampling': None}
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 5, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': None}
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'rmsprop', 'SGD'], 'ordered': False}

# %%
tuner.search(X3_train, y3_train, epochs=100, validation_split=0.2, verbose=1) #обучение
# Out:
# Trial 5 Complete [00h 00m 18s]
# val_mean_absolute_error: 0.7089817523956299
#
# Best val_mean_absolute_error So Far: 0.7089817523956299
# Total elapsed time: 00h 01m 34s
# INFO:tensorflow:Oracle triggered exit

# %%
#tuner.results_summary()

# %%
best_model = tuner.get_best_models(num_models=1)[0] #полуаем лучшую модель
loss, mae = best_model.evaluate(X3_test, y3_test) #метрики лучшей модели
print('Точность сети:', 100 - (mae / y3_test.mean() * 100))
# Out:
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7552 - mean_absolute_error: 0.7552
# Точность сети: 74.41249370205179

# %%
best_model.summary() #архитектура лучшей модели
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 24)                312
#
#  dense_1 (Dense)             (None, 32)                800
#
#  dense_2 (Dense)             (None, 96)                3168
#
#  dense_3 (Dense)             (None, 96)                9312
#
#  dense_4 (Dense)             (None, 32)                3104
#
#  dense_5 (Dense)             (None, 1)                 33
#
# ...
# Total params: 16,729
# Trainable params: 16,729
# Non-trainable params: 0
# _________________________________________________________________
